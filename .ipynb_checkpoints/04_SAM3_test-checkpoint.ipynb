# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import sys
from pathlib import Path

SAM3_REPO = Path("./sam3").resolve()
sys.path.append(str(SAM3_REPO))

import pkg_resources
print("pkg_resources OK")

from sam3.model_builder import build_sam3_image_model
from sam3.model.sam3_image_processor import Sam3Processor
print("SAM3 imports OK")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 7
#       4 SAM3_REPO = Path("./sam3").resolve()
#       5 sys.path.append(str(SAM3_REPO))
# ----> 7 import pkg_resources
#       8 print("pkg_resources OK")
#      10 from sam3.model_builder import build_sam3_image_model
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
# !python3 -m pip show setuptools
# !python3 -c "import sys; print(sys.executable)"
# Out:
# Name: setuptools
# Version: 81.0.0
# Summary: Easily download, build, install, upgrade, and uninstall Python packages
# Home-page:
# Author:
# Author-email: Python Packaging Authority <distutils-sig@python.org>
# License-Expression: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages
# Requires:
# Required-by: jupyterlab, torch
# /Library/Frameworks/Python.framework/Versions/3.13/bin/python3
